# %% [markdown]
# <a href="https://colab.research.google.com/github/nerowxrld/struktur-data/blob/main/latihan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mahasiswa = ["nero" , "budi" , "gani" , "niga"]
print (mahasiswa)
# Out:
# ['nero', 'budi', 'gani', 'niga']

# %%
mahasiswa.append ("nigger")
print ("setelah ditambahkan append")
print (mahasiswa)
# Out:
# setelah ditambahkan append
# ['nero', 'budi', 'gani', 'niga', 'nigger', 'nigger']
